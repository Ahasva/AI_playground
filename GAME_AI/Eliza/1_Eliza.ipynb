# %%
import sys
print(sys.version)

import numpy as np
import pygame
print(f"NumPy version: {np.__version__}")
print(f"Pygame version: {pygame.ver}")
# Out:
# 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:07:49) [Clang 20.1.8 ]
# NumPy version: 2.4.2
# Pygame version: 2.6.1

# %% [markdown]
# # Attribution

# %% [markdown]
# <b>Gaulke, Jens (2026). Spiele-KI mit Python programmieren. Rheinwerk Verlag: Bonn.
#
# Note:
# The following project is based on chapter 3 of Jens Gaulke's insightful book. Copyright is with Rheinwerk Verlag. Inspiration and source code taken from the book is solely used for training perposes.
